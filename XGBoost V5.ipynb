# %%
import numpy as np
import mltools as ml
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(9)

# %%
X_train = np.genfromtxt('data/X_train.txt', delimiter=None)
Y_train = np.genfromtxt('data/Y_train.txt', delimiter=None)
X_test = np.genfromtxt('data/X_test.txt', delimiter=None)

# %% [markdown]
# #### Rescaling Data

# %%
X_train_rescaled, parameters = ml.rescale(X_train)
X_test_rescaled, _ = ml.rescale(X_test, parameters)

# %% [markdown]
# #### Split data into Train and Validate

# %%
X_split_train, X_split_validation, Y_split_train, Y_split_validation = \
                                                train_test_split(X_train_rescaled, Y_train, test_size = 0.2)

# %% [markdown]
# #### Applying XGBoost

# %%
xlf = xgb.XGBRegressor(max_depth=12, 
                        learning_rate=0.05, 
                        n_estimators=2000, 
                        silent=True, 
                        objective='binary:logistic', 
                        nthread=6, 
                        min_child_weight=6, 
                        max_delta_step=0, 
                       subssample=0.8,
                       colsample_bytree=0.8,
                        colsample_bylevel=1,
                        scale_pos_weight=1, 
                        seed=1440, 
                        eval_metric='auc',
                        missing=None)

# %%
xlf.fit(X_split_train, Y_split_train, eval_metric='auc', verbose = True, \
        eval_set = [(X_split_validation, Y_split_validation)], early_stopping_rounds=50)

# xlf.fit(X_train_rescaled, Y_train, verbose=True)
# Out:
# [0]	validation_0-auc:0.692325
# Will train until validation_0-auc hasn't improved in 50 rounds.
# [1]	validation_0-auc:0.705501
# [2]	validation_0-auc:0.711415
# [3]	validation_0-auc:0.715192
# [4]	validation_0-auc:0.718691
# [5]	validation_0-auc:0.730594
# [6]	validation_0-auc:0.732754
# [7]	validation_0-auc:0.733368
# [8]	validation_0-auc:0.73372
# [9]	validation_0-auc:0.733863
# [10]	validation_0-auc:0.735174
# [11]	validation_0-auc:0.736072
# [12]	validation_0-auc:0.737182
# [13]	validation_0-auc:0.737081
# [14]	validation_0-auc:0.737951
# [15]	validation_0-auc:0.738844
# [16]	validation_0-auc:0.742076
# [17]	validation_0-auc:0.74224
# [18]	validation_0-auc:0.742517
# [19]	validation_0-auc:0.742332
# [20]	validation_0-auc:0.742537
# [21]	validation_0-auc:0.74266
# [22]	validation_0-auc:0.742819
# [23]	validation_0-auc:0.74307
# [24]	validation_0-auc:0.743893
# [25]	validation_0-auc:0.744542
# [26]	validation_0-auc:0.744986
# [27]	validation_0-auc:0.745342
# [28]	validation_0-auc:0.745321
# [29]	validation_0-auc:0.745455
# [30]	validation_0-auc:0.745741
# [31]	validation_0-auc:0.746755
# [32]	validation_0-auc:0.747295
# [33]	validation_0-auc:0.747639
# [34]	validation_0-auc:0.747746
# [35]	validation_0-auc:0.748537
# [36]	validation_0-auc:0.748922
# [37]	validation_0-auc:0.749422
# [38]	validation_0-auc:0.749827
# [39]	validation_0-auc:0.749934
# [40]	validation_0-auc:0.750368
# [41]	validation_0-auc:0.750761
# [42]	validation_0-auc:0.751394
# [43]	validation_0-auc:0.751509
# [44]	validation_0-auc:0.752859
# [45]	validation_0-auc:0.753139
# [46]	validation_0-auc:0.75329
# [47]	validation_0-auc:0.753747
# [48]	validation_0-auc:0.754156
# [49]	validation_0-auc:0.754161
# [50]	validation_0-auc:0.754427
# [51]	validation_0-auc:0.754635
# [52]	validation_0-auc:0.754742
# [53]	validation_0-auc:0.754996
# [54]	validation_0-auc:0.755756
# [55]	validation_0-auc:0.755823
# [56]	validation_0-auc:0.756256
# [57]	validation_0-auc:0.75676
# [58]	validation_0-auc:0.757089
# [59]	validation_0-auc:0.757119
# [60]	validation_0-auc:0.757289
# [61]	validation_0-auc:0.757572
# [62]	validation_0-auc:0.75779
# [63]	validation_0-auc:0.758132
# [64]	validation_0-auc:0.758352
# [65]	validation_0-auc:0.75869
# [66]	validation_0-auc:0.759095
# [67]	validation_0-auc:0.75917
# [68]	validation_0-auc:0.759517
# [69]	validation_0-auc:0.759638
# [70]	validation_0-auc:0.759879
# [71]	validation_0-auc:0.759947
# [72]	validation_0-auc:0.760163
# [73]	validation_0-auc:0.760299
# [74]	validation_0-auc:0.760719
# [75]	validation_0-auc:0.760795
# [76]	validation_0-auc:0.760866
# [77]	validation_0-auc:0.760998
# [78]	validation_0-auc:0.761262
# [79]	validation_0-auc:0.76139
# [80]	validation_0-auc:0.761523
# [81]	validation_0-auc:0.761962
# [82]	validation_0-auc:0.762081
# [83]	validation_0-auc:0.762173
# [84]	validation_0-auc:0.762296
# [85]	validation_0-auc:0.762464
# [86]	validation_0-auc:0.762683
# [87]	validation_0-auc:0.763058
# [88]	validation_0-auc:0.763284
# [89]	validation_0-auc:0.763305
# [90]	validation_0-auc:0.763368
# [91]	validation_0-auc:0.764038
# [92]	validation_0-auc:0.764094
# [93]	validation_0-auc:0.764514
# [94]	validation_0-auc:0.764714
# [95]	validation_0-auc:0.76483
# [96]	validation_0-auc:0.764908
# [97]	validation_0-auc:0.765016
# [98]	validation_0-auc:0.76512
# [99]	validation_0-auc:0.765281
# [100]	validation_0-auc:0.765398
# [101]	validation_0-auc:0.765461
# [102]	validation_0-auc:0.765685
# [103]	validation_0-auc:0.765675
# [104]	validation_0-auc:0.765864
# [105]	validation_0-auc:0.765908
# [106]	validation_0-auc:0.765934
# [107]	validation_0-auc:0.766003
# [108]	validation_0-auc:0.766201
# [109]	validation_0-auc:0.766395
# [110]	validation_0-auc:0.766561
# [111]	validation_0-auc:0.766895
# [112]	validation_0-auc:0.767051
# [113]	validation_0-auc:0.76721
# [114]	validation_0-auc:0.767362
# [115]	validation_0-auc:0.76756
# [116]	validation_0-auc:0.767774
# [117]	validation_0-auc:0.767921
# [118]	validation_0-auc:0.767948
# [119]	validation_0-auc:0.768526
# [120]	validation_0-auc:0.768778
# [121]	validation_0-auc:0.768818
# [122]	validation_0-auc:0.768843
# [123]	validation_0-auc:0.768947
# [124]	validation_0-auc:0.769031
# [125]	validation_0-auc:0.769106
# [126]	validation_0-auc:0.769199
# [127]	validation_0-auc:0.769372
# [128]	validation_0-auc:0.769504
# [129]	validation_0-auc:0.769601
# [130]	validation_0-auc:0.770164
# [131]	validation_0-auc:0.77019
# [132]	validation_0-auc:0.770531
# [133]	validation_0-auc:0.770749
# [134]	validation_0-auc:0.770809
# [135]	validation_0-auc:0.770813
# [136]	validation_0-auc:0.77092
# [137]	validation_0-auc:0.770998
# [138]	validation_0-auc:0.771284
# [139]	validation_0-auc:0.771568
# [140]	validation_0-auc:0.771841
# [141]	validation_0-auc:0.771851
# [142]	validation_0-auc:0.771881
# [143]	validation_0-auc:0.77199
# [144]	validation_0-auc:0.771987
# [145]	validation_0-auc:0.77209
# [146]	validation_0-auc:0.772095
# [147]	validation_0-auc:0.772111
# [148]	validation_0-auc:0.772193
# [149]	validation_0-auc:0.772268
# [150]	validation_0-auc:0.772384
# [151]	validation_0-auc:0.772489
# [152]	validation_0-auc:0.772608
# [153]	validation_0-auc:0.772713
# [154]	validation_0-auc:0.772813
# [155]	validation_0-auc:0.77307
# [156]	validation_0-auc:0.773031
# [157]	validation_0-auc:0.773134
# [158]	validation_0-auc:0.773176
# [159]	validation_0-auc:0.773496
# [160]	validation_0-auc:0.773508
# [161]	validation_0-auc:0.773518
# [162]	validation_0-auc:0.773651
# [163]	validation_0-auc:0.773706
# [164]	validation_0-auc:0.773746
# [165]	validation_0-auc:0.773738
# [166]	validation_0-auc:0.773843
# [167]	validation_0-auc:0.773895
# [168]	validation_0-auc:0.77419
# [169]	validation_0-auc:0.774226
# [170]	validation_0-auc:0.774379
# [171]	validation_0-auc:0.774572
# [172]	validation_0-auc:0.774848
# [173]	validation_0-auc:0.774875
# [174]	validation_0-auc:0.774863
# [175]	validation_0-auc:0.774863
# [176]	validation_0-auc:0.774923
# [177]	validation_0-auc:0.775038
# [178]	validation_0-auc:0.775186
# [179]	validation_0-auc:0.775224
# [180]	validation_0-auc:0.775544
# [181]	validation_0-auc:0.775729
# [182]	validation_0-auc:0.77581
# [183]	validation_0-auc:0.775812
# [184]	validation_0-auc:0.775841
# [185]	validation_0-auc:0.775857
# [186]	validation_0-auc:0.77586
# [187]	validation_0-auc:0.775877
# [188]	validation_0-auc:0.776011
# [189]	validation_0-auc:0.776142
# [190]	validation_0-auc:0.77617
# [191]	validation_0-auc:0.7762
# [192]	validation_0-auc:0.776207
# [193]	validation_0-auc:0.776202
# [194]	validation_0-auc:0.776282
# [195]	validation_0-auc:0.776404
# [196]	validation_0-auc:0.776408
# [197]	validation_0-auc:0.776428
# [198]	validation_0-auc:0.776434
# [199]	validation_0-auc:0.776505
# [200]	validation_0-auc:0.77663
# [201]	validation_0-auc:0.776634
# [202]	validation_0-auc:0.776784
# [203]	validation_0-auc:0.776841
# [204]	validation_0-auc:0.776972
# [205]	validation_0-auc:0.777017
# [206]	validation_0-auc:0.777034
# [207]	validation_0-auc:0.777069
# [208]	validation_0-auc:0.77718
# [209]	validation_0-auc:0.77733
# [210]	validation_0-auc:0.777477
# [211]	validation_0-auc:0.777544
# [212]	validation_0-auc:0.777556
# [213]	validation_0-auc:0.777639
# [214]	validation_0-auc:0.777822
# [215]	validation_0-auc:0.777964
# [216]	validation_0-auc:0.778001
# [217]	validation_0-auc:0.778043
# [218]	validation_0-auc:0.778083
# [219]	validation_0-auc:0.778077
# [220]	validation_0-auc:0.778077
# [221]	validation_0-auc:0.778144
# [222]	validation_0-auc:0.778142
# [223]	validation_0-auc:0.778143
# [224]	validation_0-auc:0.778144
# [225]	validation_0-auc:0.778401
# [226]	validation_0-auc:0.778508
# [227]	validation_0-auc:0.778544
# [228]	validation_0-auc:0.778541
# [229]	validation_0-auc:0.778618
# [230]	validation_0-auc:0.77865
# [231]	validation_0-auc:0.778657
# [232]	validation_0-auc:0.778778
# [233]	validation_0-auc:0.778801
# [234]	validation_0-auc:0.778827
# [235]	validation_0-auc:0.778851
# [236]	validation_0-auc:0.778875
# [237]	validation_0-auc:0.77905
# [238]	validation_0-auc:0.779148
# [239]	validation_0-auc:0.779144
# [240]	validation_0-auc:0.779129
# [241]	validation_0-auc:0.779162
# [242]	validation_0-auc:0.779343
# [243]	validation_0-auc:0.779332
# [244]	validation_0-auc:0.779446
# [245]	validation_0-auc:0.779615
# [246]	validation_0-auc:0.77968
# [247]	validation_0-auc:0.779744
# [248]	validation_0-auc:0.779773
# [249]	validation_0-auc:0.779807
# [250]	validation_0-auc:0.779878
# [251]	validation_0-auc:0.77989
# [252]	validation_0-auc:0.779863
# [253]	validation_0-auc:0.779904
# [254]	validation_0-auc:0.779939
# [255]	validation_0-auc:0.780046
# [256]	validation_0-auc:0.780073
# [257]	validation_0-auc:0.780141
# [258]	validation_0-auc:0.780178
# [259]	validation_0-auc:0.780333
# [260]	validation_0-auc:0.780385
# [261]	validation_0-auc:0.780394
# [262]	validation_0-auc:0.780531
# [263]	validation_0-auc:0.780606
# [264]	validation_0-auc:0.780707
# [265]	validation_0-auc:0.780814
# [266]	validation_0-auc:0.780871
# [267]	validation_0-auc:0.780875
# [268]	validation_0-auc:0.780859
# [269]	validation_0-auc:0.780871
# [270]	validation_0-auc:0.780944
# [271]	validation_0-auc:0.780998
# [272]	validation_0-auc:0.781074
# [273]	validation_0-auc:0.78107
# [274]	validation_0-auc:0.781059
# [275]	validation_0-auc:0.781141
# [276]	validation_0-auc:0.781335
# [277]	validation_0-auc:0.781558
# [278]	validation_0-auc:0.781577
# [279]	validation_0-auc:0.781618
# [280]	validation_0-auc:0.781745
# [281]	validation_0-auc:0.781762
# [282]	validation_0-auc:0.781763
# [283]	validation_0-auc:0.781751
# [284]	validation_0-auc:0.781746
# [285]	validation_0-auc:0.781787
# [286]	validation_0-auc:0.78196
# [287]	validation_0-auc:0.781985
# [288]	validation_0-auc:0.782128
# [289]	validation_0-auc:0.782209
# [290]	validation_0-auc:0.782224
# [291]	validation_0-auc:0.782272
# [292]	validation_0-auc:0.782273
# [293]	validation_0-auc:0.782314
# [294]	validation_0-auc:0.78234
# [295]	validation_0-auc:0.782349
# [296]	validation_0-auc:0.782456
# [297]	validation_0-auc:0.782452
# [298]	validation_0-auc:0.782455
# [299]	validation_0-auc:0.782523
# [300]	validation_0-auc:0.782543
# [301]	validation_0-auc:0.782685
# [302]	validation_0-auc:0.782688
# [303]	validation_0-auc:0.782677
# [304]	validation_0-auc:0.782672
# [305]	validation_0-auc:0.782671
# [306]	validation_0-auc:0.782717
# [307]	validation_0-auc:0.782715
# [308]	validation_0-auc:0.782786
# [309]	validation_0-auc:0.782864
# [310]	validation_0-auc:0.783015
# [311]	validation_0-auc:0.783182
# [312]	validation_0-auc:0.783182
# [313]	validation_0-auc:0.783186
# [314]	validation_0-auc:0.783302
# [315]	validation_0-auc:0.7833
# [316]	validation_0-auc:0.783317
# [317]	validation_0-auc:0.783316
# [318]	validation_0-auc:0.783336
# [319]	validation_0-auc:0.783396
# [320]	validation_0-auc:0.783426
# [321]	validation_0-auc:0.783424
# [322]	validation_0-auc:0.783489
# [323]	validation_0-auc:0.78357
# [324]	validation_0-auc:0.783655
# [325]	validation_0-auc:0.783647
# [326]	validation_0-auc:0.783643
# [327]	validation_0-auc:0.783707
# [328]	validation_0-auc:0.783704
# [329]	validation_0-auc:0.783704
# [330]	validation_0-auc:0.783725
# [331]	validation_0-auc:0.783829
# [332]	validation_0-auc:0.783903
# [333]	validation_0-auc:0.78403
# [334]	validation_0-auc:0.784075
# [335]	validation_0-auc:0.784071
# [336]	validation_0-auc:0.784115
# [337]	validation_0-auc:0.78411
# [338]	validation_0-auc:0.784121
# [339]	validation_0-auc:0.784185
# [340]	validation_0-auc:0.784192
# [341]	validation_0-auc:0.784195
# [342]	validation_0-auc:0.784183
# [343]	validation_0-auc:0.784229
# [344]	validation_0-auc:0.78424
# [345]	validation_0-auc:0.784269
# [346]	validation_0-auc:0.784305
# [347]	validation_0-auc:0.784368
# [348]	validation_0-auc:0.784364
# [349]	validation_0-auc:0.784393
# [350]	validation_0-auc:0.784387
# [351]	validation_0-auc:0.784393
# [352]	validation_0-auc:0.784414
# [353]	validation_0-auc:0.784454
# [354]	validation_0-auc:0.78445
# [355]	validation_0-auc:0.784452
# [356]	validation_0-auc:0.784514
# [357]	validation_0-auc:0.784543
# [358]	validation_0-auc:0.78468
# [359]	validation_0-auc:0.784696
# [360]	validation_0-auc:0.784696
# [361]	validation_0-auc:0.784686
# [362]	validation_0-auc:0.784711
# [363]	validation_0-auc:0.784754
# [364]	validation_0-auc:0.784927
# [365]	validation_0-auc:0.785044
# [366]	validation_0-auc:0.785042
# [367]	validation_0-auc:0.785103

# %%
predictions = xlf.predict(X_test_rescaled)

# %%
predictions #1
# Out:
# array([ 0.82907212,  0.63176537,  0.31591514, ...,  0.27784756,
#         0.09122714,  0.12314682], dtype=float32)

# %% [markdown]
# #### Saving txt file

# %%
Yte = np.vstack((np.arange(X_test.shape[0]), predictions)).T

# %%
np.savetxt('Y_submit_XGBoost_v5.txt', Yte, '%d, %.2f', header='ID,Prob1', comments='', delimiter=',')
